# %% [markdown]
# <small><i><b>June the 2nd 2017</b> - Alliance Science Po / Columbia University- PhD Summer school</i><br>
# Thomas Roca, PhD - Agence Française de Développement<br>
# Twitter: [@Thomas Roca](https://twitter.com/Thomas_Roca) || *[Lecture's Github Folder](https://github.com/ThomasRoca/Lecture-Columbia-Science-Po-2017)*</small><br>
#
#
# ## Introduction to Datavisualization
#     "A data scientist is someone who is better at statistics than any software engineer and better at software engineering than any statistician."
#
#
# <img src='http://stats4dev.com/prez/cool_data_3.gif'>

# %% [markdown]
# # 1. What is datavisualization
#
# - It must diasplay data..
# - interactive inforgraphic
# - Most of the time HTML and javascript
#
# Example: http://data.afd.fr/

# %%
HTML('''<iframe src="http://www.oecdbetterlifeindex.org/#/11111111111" scrolling="no" frameborder="0" width=100%" height="675"></iframe>''')
# Out:
# <iframe src="http://www.oecdbetterlifeindex.org/#/11111111111" scrolling="no" frameborder="0" width=100%" height="675"></iframe>

# %% [markdown]
# ### Basic instroduction ###
# -   using packages with Stata and Python (15 min)
# -	SIG using [Carto](https://carto.com/) and [leaflet](http://leafletjs.com/)
# -	Basic introduction to [HTML](https://www.w3schools.com/html/default.asp), [CSS](https://www.w3schools.com/css/default.asp)
# -	JavaScript & dataviz
#     + quick intro to [JavaScript](https://www.w3schools.com/js/default.asp)
#     + Intro to [JSON](https://en.wikipedia.org/wiki/JSON)
#     + dataviz the example of [highchart](https://www.highcharts.com/) and [d3.js](https://d3js.org/)

# %% [markdown]
# # Dataviz for all: packages and software..
# - Stata (see my plugins [Himap](http://econpapers.repec.org/software/bocbocode/S457920.htm), [3D plot](http://econpapers.repec.org/software/bocbocode/S457922.htm), etc. :)
# - R: [ggplot](http://www.statmethods.net/advgraphs/ggplot2.html)
# - Python: [matplotlib](https://matplotlib.org/gallery.html), [Seaborn](https://seaborn.pydata.org/), [bokeh](), [d3js package](http://nvd3.org/), etc.

# %% [markdown]
#  ### Funky stuff... like XKCD

# %%
from IPython.display import Image
Image('http://jakevdp.github.com/figures/xkcd_version.png')

# %% [markdown]
# ## Example of Matplotlib for HDR2015

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
Year=np.array([1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011])

#Productivity
US_p=np.array([100,103.3014096,105.2530664,107.1445328,109.2128503,114.1487449,111.8010891,114.9564671,115.308162,120.5297607,121.2367635,124.5858159,130.5790409,139.5242903,146.2320682,151.7957437,154.7141778,154.7677332,160.6847743,162.9637761,163.470189,174.0190279,181.4770087,190.5291264,185.9504221,192.3939511,202.8309182,210.468272,212.3561129,215.2584574,213.6200006,225.2725304,227.2143176,243.3043327,250.1417376,259.0358946,263.2471097,281.4700738,292.3211162,293.8618617,297.3530599,305.628367,317.4000172,325.8365609,339.4042571,350.9844405,362.9905603,377.9786019,397.8735771,422.1302571,454.9260367,464.3022204,512.1115487,555.6012635,604.1336965,632.118673,653.6456222,688.2453704,674.900632,702.9663436,781.915389,797.5705382])
France_p=np.array([100,104.4784298,103.4413049,105.7293641,112.1571925,114.4112798,120.9047753,122.3220121,125.2185794,128.6481285,136.7275667,144.2869002,151.2186001,165.460256,170.2880304,185.3685356,198.6106266,209.9374644,233.7349511,248.32795,265.1901913,278.5620005,284.5480029,298.4344243,326.3294799,333.6319977,349.0207734,368.735091,377.9600239,393.4983054,400.5358038,418.0209231,440.4787713,460.8166829,475.0107301,496.1974851,499.3509108,504.7186452,524.4409629,546.3938301,557.3915267,571.9610497,587.2924174,606.1041738,643.6823382,669.9322166,672.9654306,705.7525384,740.6184052,772.8410799,818.002482,828.2792508,859.7924734,888.3666385,921.3607266,963.8959974,1001.528675,1028.635601,992.8604891,991.9123876,1052.331439,1075.737975])
Japan_p=np.array([100,125.0000473,131.2090751,149.1566693,158.8382573,165.2431356,182.55445,204.7813993,192.419427,226.739601,266.2138251,302.1652916,319.3841811,345.595205,392.395648,410.3128246,449.1871922,506.635426,566.8278336,649.0976575,729.4150669,773.4027031,848.2401996,924.895592,948.2837293,975.2146565,1034.354328,1075.315047,1118.993196,1210.590004,1229.657024,1269.578434,1314.163207,1317.139213,1344.82546,1472.756996,1477.889611,1540.689499,1613.403222,1699.371447,1820.963729,1915.290741,1935.764438,1973.497258,2007.960256,2140.159086,2239.706111,2318.198994,2342.222519,2403.733552,2531.244246,2477.256385,2543.511083,2678.145429,2837.046105,3022.579207,3092.1164,3278.341613,3415.957599,3201.570906,3674.289123,3570.501147])
#hourly wages
US_w=np.array([100,101.8964668,106.438877,111.4074358,115.7375678,120.4421562,126.3180785,129.6228298,132.0573978,135.7397278,139.1376355,141.7910027,145.4311113,147.4540833,151.4989856,152.2813247,154.4817083,158.2634315,163.2353971,166.1192039,168.2615767,170.6854444,173.894616,176.2220153,176.2306562,181.1633026,185.370173,189.5957739,190.4078728,190.514987,191.7890817,192.6994021,198.4625267,196.0960563,194.7678607,197.9345175,203.504863,203.1601599,202.9341732,200.4019088,200.114878,204.6360649,209.0086854,208.5604391,209.3170708,207.6312569,205.6737864,206.2405116,216.0269951,220.8894479,230.2643958,232.4569036,241.360629,254.9662399,250.2288741,250.1909213,247.1475573,248.062292,249.0886482,260.2828443,258.9306097,257.6565])
France_w=np.array([100,106.7498219,117.0619556,124.8338519,133.4280232,142.5364715,157.9401988,168.8326385,168.9978624,174.627203,181.7555765,193.5915896,202.3254014,214.2376159,224.3637927,238.9766241,248.4418841,265.1189629,290.229952,310.3026399,329.7305689,346.5256082,367.858602,391.8918703,410.3561427,449.1670321,455.3982792,475.138127,491.7556568,502.5969315,509.2552796,520.9726878,551.8304392,562.805952,576.4820996,590.0209514,600.3113075,605.2826294,611.0729842,622.6368105,630.1514295,646.2572864,661.16366,674.5457564,686.3973985,695.2709966,693.0300723,709.2868511,711.9813282,731.9924164,755.9757876,764.3952234,793.772079,796.981536,805.058476,818.2112984,836.6649412,840.2005407,838.2189836,871.9327718,874.5599925,877.5879489])
Japan_w=np.array([100,108.8056534,118.4787251,117.54999,120.9823196,127.4365165,132.8319585,134.8380871,138.1057333,152.3146087,162.1500853,179.3409676,192.3972377,199.0515768,215.4523925,228.2139276,239.3977206,258.5363458,284.412512,319.705692,354.0329996,383.7171628,422.0400302,461.4903172,491.4474942,512.1535211,503.9342643,514.6234076,525.6590964,539.7868422,532.5632593,544.5806963,555.3646304,560.308636,563.878743,573.4275468,593.7206044,611.5217506,621.4710816,644.0357936,667.4932795,687.98305,700.8224243,710.7097189,719.8789913,744.6148319,750.9364739,761.8836356,776.2914631,777.4882953,778.1765001,794.3097936,802.1701734,787.4262029,778.1581011,768.5775367,754.2975412,752.3122578,767.7725456,781.1448363,777.6227545,796.3582535])

country_list=['Japan','France','US']

for country in country_list:
    #Set serie 1 and 2
    y1=vars()[country+'_w']
    y2=vars()[country+'_p']
    
    # Find the max of the two series to set up y-axis max
    maxy=max(np.amax(y1),np.amax(y2))
    
    #set country and colors for the series
    country=country
    color_y1='#355CA8'
    color_y2='#BC456B'

    fig,(ax)= plt.subplots( figsize=(7,7),dpi=400)
    plt.gca().set_color_cycle([color_y1,color_y2])
    ax.plot(Year, y1, Year, y2)

    ax.fill_between(Year, y1, y2, where=y2<=y1, facecolor=color_y1, alpha=0.3, interpolate=True)
    ax.fill_between(Year, y1, y2, where=y2>=y1, facecolor=color_y2, alpha=0.3, interpolate=True)
    ax.set_ylim((50, maxy))
    ax.set_xlim((1945, 2011))
    ax.set_xticks([1945,1950,1955,1960,1965,1970,1975,1980,1985,1990,1995,2000,2005,2011])
    ax.tick_params(axis='x', colors='#7c7c7c')
    ax.tick_params(axis='y', colors='#7c7c7c')
    
    ax.set_title(country, fontsize=15, color='#535459')
  
    ax.yaxis.label.set_color('#7c7c7c')
    ax.xaxis.label.set_color('#7c7c7c')
    
    leg = plt.legend(['Wages','Productivity'],loc=2, fontsize=12, frameon=False)
    for text in leg.get_texts():
        text.set_color("#535459")
        
    ax.spines['left'].set_bounds(100, maxy)
    ax.spines['left'].set_color('#dddddd') 
    ax.spines['bottom'].set_color('#dddddd') 

    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    
    ax.annotate('[1950=100]', xy=(1948,maxy), xycoords='data', xytext=(0,0), textcoords='offset points',size=11, color="#535459")
 
    fig.savefig(country+'.svg', bbox_inches='tight')
    fig.savefig(country+'.png', bbox_inches='tight')
    fig.savefig(country+'.pdf', bbox_inches='tight')
    plt.show()
# Out:
# C:\Python34\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Using javascript library within Python
#
# ... The example of d3.js

# %%
from string import Template
from IPython.display import HTML
from nvd3 import pieChart
type = 'pieChart'
chart = pieChart(name=type, color_category='category20c', height=450, width=450)
xdata = ["Orange", "Banana", "Pear", "Kiwi", "Apple", "Strawberry", "Pineapple"]
ydata = [3, 4, 0, 1, 5, 7, 3]
extra_serie = {"tooltip": {"y_start": "", "y_end": " calories"}}
chart.add_serie(y=ydata, x=xdata, extra=extra_serie)
chart.buildcontent() 
d3script='<script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.1/nv.d3.min.js"></script>'
f = open("chart_d3.html",'w')
f.write(d3script+chart.htmlcontent)
f.close()
HTML('<iframe src="http://stats4dev.com/prez/chart_d3.html" scrolling="no" frameborder="0" width=100%" height="500px"></iframe>')
# Out:
# <iframe src="http://stats4dev.com/prez/chart_d3.html" scrolling="no" frameborder="0" width=100%" height="500px"></iframe>

# %% [markdown]
# ## GIS with web soft: Carto
#
# NB. Carto rocks... but its proprietary..
#
# **A little demo...**
# https://rocathomas.carto.com/dashboard

# %% [markdown]
# ## GIS with Python: Leaflet Library package - [folium](https://github.com/python-visualization/folium)

# %%
import folium
from IPython.display import HTML
# fichier au format GeoJSON
mongeojson = '../ipyleaflet/sahel.json'
carte = folium.Map(location=[12.2383,-1.56159],tiles='OpenStreetMap', zoom_start=5)
carte.geo_json(geo_path=mongeojson)
folium.Map.save(carte, "map.html")
HTML('<iframe src="http://stats4dev.com/prez/map.html" "scrolling="no" frameborder="0" width=100%" height="500px"></iframe>')
# Out:
# C:\Python34\lib\site-packages\folium\folium.py:504: UserWarning: This method is deprecated. Please use Map.choropleth instead.
#   warnings.warn('This method is deprecated. '
# <iframe src="http://stats4dev.com/prez/map.html" "scrolling="no" frameborder="0" width=100%" height="500px"></iframe>

# %% [markdown]
# # II. Enough playing, let's dig'in
#
# Let's code a bit now.. HTML, CSS, Javascript

# %%
from IPython.core.display import display, HTML
display(HTML('''

<h2> a. Basic introduction to HTML, CSS</h2>             
<br>
<h1>Hello world ! </h1>
<br>
<span style="color:red; font-size:36px; font-family:Magneto ">
Hello world! with style</span>
            
'''))
# Out:
# <h2> a. Basic introduction to HTML, CSS</h2>
# <br>
# <h1>Hello world ! </h1>
# <br>
# <span style="color:red; font-size:36px; font-family:Magneto ">
# Hello world! with style</span>

# %%
display(HTML('''
<h2> B. Introduction to SVG</h2>
<br>
<h1>Hello SVG</h1>
<svg width="100" height="100">
   <circle cx="50" cy="50" r="40" stroke="rgb(0, 119, 181)" stroke-width="4" fill="blue" />
</svg> 

'''))
# Out:
# <h2> B. Introduction to SVG</h2>
# <br>
# <h1>Hello SVG</h1>
# <svg width="100" height="100">
#    <circle cx="50" cy="50" r="40" stroke="rgb(0, 119, 181)" stroke-width="4" fill="blue" />
# </svg>

# %% [markdown]
# ## SVG : Vector versus pixel
#
# <img src="http://i.vimeocdn.com/video/131954497_1280x720.jpg" width="75%">

# %%
display(HTML('''
<iframe width="100%" height="300" src="//jsfiddle.net/fxcjzufw/1/embedded/html,result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe> '''))
# Out:
# <iframe width="100%" height="300" src="//jsfiddle.net/fxcjzufw/1/embedded/html,result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>

# %% [markdown]
# ## C Basic introduction to Javascript
#
# - jsfiddle
# - jquerry
# - console

# %%
# Python 
vector=["H","e","l","l","o"," ","w","o","r","l","d","!"]

for letter in vector:
    print(letter)

# %%
# %%javascript
#
# var vector=["H","e","l","l","o"," ","w","o","r","l","d","!"]
# for (letter in vector) {
# document.write(vector[letter])
# }

# %% [markdown]
# ## Dataviz: leveraging javascript libraries
# - Highcharts
# - d3js
# - leafleft

# %% [markdown]
# # C. When Data comes in : API, JSON, XLM, etc.

# %% [markdown]
# ## What is an API ?
# ![](http://stats4dev.com/prez/api.png)

# %% [markdown]
# ### Why using an API
#
# - Programmatic access = Automate
# - Always up to date

# %% [markdown]
# ## Introduction to the code behind an API
#
# http://api.dataspace.fr/?dataset=WDI&indicator=NY.GDP.MKTP.KD.ZG&year=2001&country=FRA

# %% [markdown]
# ###  The JSON format
#
# JSON datasets are text data. It uses keys to organize the data and is readable by JavaScript.
# Here is an example of the data structure.
# ```javascript
# {
#   "indicator_value": {
#     "103606": {
#       "AFG": {
#         "2009": "0.404",
#         "2010": "0.426",
#         "2011": "0.428",
#         "2012": "0.443",
#         "2013": "0.445"
#       }
#     }
#   },
#   "country_name": {
#     "AFG": "Afghanistan"
#   },
#   "indicator_name": {
#     "103606": "HDI: Income index"
#   }
# }```
#
# To read it easily you can use online editor such as [json editor](http://www.jsoneditoronline.org/)
# The following request:<span style="color:#1174d5;"> json.indicator_value["103606"].AFG["2005"]</span> will return the value: <span style="color:#1174d5;">0.366</span>

# %% [markdown]
# ## C. How to use API
# - Exemple of a request

# %%
from IPython.display import HTML
HTML('''<iframe width="100%" height="400" src="//jsfiddle.net/ThomasRoca/zceqa7jf/embedded/js,result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>''')
# Out:
# <iframe width="100%" height="400" src="//jsfiddle.net/ThomasRoca/zceqa7jf/embedded/js,result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>

# %% [markdown]
# Then it is easy to parse the data to create a dataviz:

# %% [markdown]
# ## A bit more complex..
# ## <span style="color:#336da9;"> Visualizing all the WDI from the World Bank!</span>
# ## The Big Browser project

# %%
from IPython.display import HTML
HTML('''<iframe width="100%" height="485" src="http://jsfiddle.net/ThomasRoca/1vpypyc9/embedded/result,js,html,css" allowfullscreen="allowfullscreen" scrolling:"no" frameborder="0"></iframe>''')
# Out:
# <iframe width="100%" height="485" src="http://jsfiddle.net/ThomasRoca/1vpypyc9/embedded/result,js,html,css" allowfullscreen="allowfullscreen" scrolling:"no" frameborder="0"></iframe>

# %% [markdown]
# ## Use case 2: Scrap the web !
# Scrapping the web with [YQL](https://developer.yahoo.com/yql/)(and twitter again)
# example: [wacky twitter race](https://www.highcharts.com/blog/post/query-api-twitter-wacky-race-using-highcharts/) !

# %% [markdown]
# # Do it yourself:  Building a Vélib App' !
#
# Link API: https://developer.jcdecaux.com/

# %%
HTML('''
<iframe width="100%" height="300" src="//jsfiddle.net/ThomasRoca/zceqa7jf/embedded/js,html,result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>
''')
# Out:
# <iframe width="100%" height="300" src="//jsfiddle.net/ThomasRoca/zceqa7jf/embedded/js,html,result/" allowfullscreen="allowfullscreen" frameborder="0"></iframe>

# %% [markdown]
# ## To get further
#
# Blog highcharts:
# - [Open Data API for Chart Creation (Part 1)](http://www.highcharts.com/blog/233-world-bank-open-data-api-highcharts-part1)
# - [Open Data API for Chart Creation (Part 2)](http://www.highcharts.com/blog/235-open-data-api-for-chart-creation-part-2)
# - [Way to react to API failure](http://www.highcharts.com/blog/238-way-to-react-to-api-failure)

# %%
# %%html
# <style>table,td,tr,th {border:0px solid black!important}
# </style>
# Out:
# <style>table,td,tr,th {border:0px solid black!important}
# </style>

# %%
from IPython.display import HTML
from IPython.display import IFrame
